# %%
import numpy as np
import tensorflow as tf
# Out:
# 2023-08-04 00:11:41.291501: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-04 00:11:41.704723: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu,True)
# Out:
# 2023-08-04 00:11:42.238356: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 00:11:42.253973: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 00:11:42.254118: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
import pickle
f = open("ds.pkl",'rb')
x,y = pickle.load(f)
f.close()

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.GRU(64, activation='tanh', input_shape=(9,1)))
model.add(tf.keras.layers.Dense(1))
# Out:
# 2023-08-04 00:11:42.269219: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 00:11:42.269426: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 00:11:42.269591: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 00:11:42.659418: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 00:11:42.659570: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 00:11:42.659679: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 00:11:42.659779: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9666 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:0a:00.0, compute capability: 8.6
# 2023-08-04 00:11:42.758880: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:42.759418: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:42.759916: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mse')

# %%
model.fit(x,y,epochs=100)
# Out:
# Epoch 1/100
# 2023-08-04 00:11:43.036718: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:43.037582: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:43.038216: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-04 00:11:43.367719: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:43.368554: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:43.369185: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-04 00:11:44.226033: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-08-04 00:11:44.302711: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-08-04 00:11:44.324167: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f42d0131370 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-04 00:11:44.324193: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3080 Ti, Compute Capability 8.6
# 2023-08-04 00:11:44.327109: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-08-04 00:11:44.417498: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4/4 [==============================] - 2s 4ms/step - loss: 1.1192
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6746
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3251
# Epoch 4/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0892
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 6/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0497
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0477
# Epoch 8/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0114
# Epoch 9/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 10/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 11/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 12/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 13/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 14/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4263e-04
# Epoch 15/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 16/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 17/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 18/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 19/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 20/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 21/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 22/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5023e-04
# Epoch 23/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4838e-04
# Epoch 24/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5869e-04
# Epoch 25/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5669e-04
# Epoch 26/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.5175e-04
# Epoch 27/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4211e-04
# Epoch 28/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.4156e-04
# Epoch 29/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.4147e-04
# Epoch 30/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5091e-04
# Epoch 31/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4122e-04
# Epoch 32/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4258e-04
# Epoch 33/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4280e-04
# Epoch 34/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4230e-04
# Epoch 35/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.3750e-04
# Epoch 36/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.7128e-04
# Epoch 37/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.6380e-04
# Epoch 38/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.5198e-04
# Epoch 39/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4938e-04
# Epoch 40/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4016e-04
# Epoch 41/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4357e-04
# Epoch 42/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5980e-04
# Epoch 43/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.6232e-04
# Epoch 44/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4570e-04
# Epoch 45/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5817e-04
# Epoch 46/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.8313e-04
# Epoch 47/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.9827e-04
# Epoch 48/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.4809e-04
# Epoch 49/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.6165e-04
# Epoch 50/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.6293e-04
# Epoch 51/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4354e-04
# Epoch 52/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.3806e-04
# Epoch 53/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4198e-04
# Epoch 54/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.4185e-04
# Epoch 55/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.4376e-04
# Epoch 56/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4063e-04
# Epoch 57/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4628e-04
# Epoch 58/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.4301e-04
# Epoch 59/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4684e-04
# Epoch 60/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4476e-04
# Epoch 61/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.4309e-04
# Epoch 62/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5136e-04
# Epoch 63/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4608e-04
# Epoch 64/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.4814e-04
# Epoch 65/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.3890e-04
# Epoch 66/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.4622e-04
# Epoch 67/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.3963e-04
# Epoch 68/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4756e-04
# Epoch 69/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5438e-04
# Epoch 70/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.3790e-04
# Epoch 71/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4612e-04
# Epoch 72/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.6558e-04
# Epoch 73/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4663e-04
# Epoch 74/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.3947e-04
# Epoch 75/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.3960e-04
# Epoch 76/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5021e-04
# Epoch 77/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5779e-04
# Epoch 78/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.3601e-04
# Epoch 79/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5679e-04
# Epoch 80/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.9155e-04
# Epoch 81/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.5456e-04
# Epoch 82/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4181e-04
# Epoch 83/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4171e-04
# Epoch 84/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4726e-04
# Epoch 85/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.7045e-04
# Epoch 86/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4983e-04
# Epoch 87/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5463e-04
# Epoch 88/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.5339e-04
# Epoch 89/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.3853e-04
# Epoch 90/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.3785e-04
# Epoch 91/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4113e-04
# Epoch 92/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.3246e-04
# Epoch 93/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4752e-04
# Epoch 94/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 95/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.7363e-04
# Epoch 96/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4692e-04
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.3891e-04
# Epoch 98/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4747e-04
# Epoch 99/100
# 4/4 [==============================] - 0s 3ms/step - loss: 9.4643e-04
# Epoch 100/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.5691e-04

# %%
model.save("gru")
# Out:
# 2023-08-04 00:11:45.791216: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:45.792055: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:45.792856: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-04 00:11:45.875799: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:45.876436: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:45.877037: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-04 00:11:45.956140: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:45.956780: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:45.957343: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-04 00:11:45.966221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,1]
# 	 [[{{node inputs}}]]
# 2023-08-04 00:11:45.969926: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,1]
# 	 [[{{node inputs}}]]
# 2023-08-04 00:11:46.042935: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:46.043692: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:46.044233: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-04 00:11:46.052779: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gru_input' with dtype float and shape [?,9,1]
# 	 [[{{node gru_input}}]]
# 2023-08-04 00:11:46.128495: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:46.129099: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:46.129628: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-04 00:11:46.138065: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gru_input' with dtype float and shape [?,9,1]
# 	 [[{{node gru_input}}]]
# 2023-08-04 00:11:46.143594: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,9,1]
# 	 [[{{node inputs}}]]
# 2023-08-04 00:11:46.147828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gru_input' with dtype float and shape [?,9,1]
# 	 [[{{node gru_input}}]]
# 2023-08-04 00:11:46.152512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,9,1]
# 	 [[{{node inputs}}]]
# 2023-08-04 00:11:46.156757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gru_input' with dtype float and shape [?,9,1]
# 	 [[{{node gru_input}}]]
# 2023-08-04 00:11:46.160709: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,9,1]
# 	 [[{{node inputs}}]]
# 2023-08-04 00:11:46.164208: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,9,1]
# 	 [[{{node inputs}}]]
# 2023-08-04 00:11:46.171212: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,9,1]
# 	 [[{{node inputs}}]]
# 2023-08-04 00:11:46.175273: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,9,1]
# 	 [[{{node inputs}}]]
# 2023-08-04 00:11:46.199179: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gru_input' with dtype float and shape [?,9,1]
# 	 [[{{node gru_input}}]]
# 2023-08-04 00:11:46.205818: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,9,1]
# 	 [[{{node inputs}}]]
# 2023-08-04 00:11:46.209879: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,9,1]
# 	 [[{{node inputs}}]]
# 2023-08-04 00:11:46.290808: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:46.291512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:46.292173: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-04 00:11:46.378508: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:46.379156: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:46.379744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-04 00:11:46.400341: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_0' with dtype float and shape [?,?,1]
# 	 [[{{node inputs_0}}]]
# 2023-08-04 00:11:46.404040: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_0' with dtype float and shape [?,?,1]
# 	 [[{{node inputs_0}}]]
# 2023-08-04 00:11:46.407669: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,9,1]
# 	 [[{{node inputs}}]]
# 2023-08-04 00:11:46.411342: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,9,1]
# 	 [[{{node inputs}}]]
# 2023-08-04 00:11:46.482710: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:46.483297: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:46.483823: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-04 00:11:46.561774: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:46.562481: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:46.562988: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-04 00:11:46.640801: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:46.641364: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:46.641866: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-04 00:11:46.718808: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-04 00:11:46.719378: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-04 00:11:46.719900: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 2023-08-04 00:11:46.758974: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'serving_default_gru_input' with dtype float and shape [?,9,1]
# 	 [[{{node serving_default_gru_input}}]]
# INFO:tensorflow:Assets written to: gru/assets
# INFO:tensorflow:Assets written to: gru/assets
